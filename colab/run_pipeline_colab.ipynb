# %%
# %cd /content

# !rm -rf stock_forecasting_regime_ensemble

# !git clone https://github.com/vitaliyporkhaev/stock_forecasting_regime_ensemble.git

# %cd /content/stock_forecasting_regime_ensemble

# !ls
# Out:
# /content
# Cloning into 'stock_forecasting_regime_ensemble'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 274 (delta 135), reused 173 (delta 60), pack-reused 0 (from 0)
# Receiving objects: 100% (274/274), 864.29 KiB | 8.00 MiB/s, done.
# Resolving deltas: 100% (135/135), done.
# /content/stock_forecasting_regime_ensemble
# colab	 environment.yml  pipeline.py  requirements.txt  tests
# configs  notebooks	  README.md    src

# %%
# %matplotlib inline
# !pip install -r requirements.txt
# !python pipeline.py
# Out:
# ...
# 2026-05-13 06:47:15.595333: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-13 06:47:15.640736: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Запуск торгового пайплайна с риск-менеджментом
#
# Тестируемые тикеры: AAPL, MSFT, GOOGL, AMZN, NVDA, META, TSLA
#
#
# Обработка тикера: AAPL
#    Загружено 4114 строк
#       LightGBM: pred std=0.004309
# 2026-05-13 06:47:19.706695: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# ...
